# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Set matplotlib inline
# %matplotlib inline

# %%
url = "https://fantasy.premierleague.com/api/bootstrap-static/"

# %%
r = requests.get(url)
json = r.json()

# %%
json.keys()
# Out:
# dict_keys(['events', 'game_settings', 'phases', 'teams', 'total_players', 'elements', 'element_stats', 'element_types'])

# %%
elements_df = pd.DataFrame(json['elements'])

# %%
elements_df.head()
# Out:
#    chance_of_playing_next_round chance_of_playing_this_round    code  \
# 0                           NaN                         None   80201
# 1                           NaN                         None  115918
# 2                           NaN                         None   47431
# 3                           NaN                         None   54694
# 4                           NaN                         None   58822
#
#    cost_change_event  cost_change_event_fall  cost_change_start  \
# 0                  0                       0                  0
# 1                  0                       0                  0
# 2                  0                       0                  0
# 3                  0                       0                  0
# 4                  0                       0                  0
#
#    cost_change_start_fall  dreamteam_count  element_type ep_next  ...  \
# 0                       0                0             1     3.6  ...
# ...

# %%
elements_df.columns
# Out:
# Index(['second_name', 'element_type', 'now_cost', 'transfers_in', 'form',
#        'selected_by_percent', 'total_points', 'value_form', 'value_season',
#        'clean_sheets'],
#       dtype='object')

# %%
elements_df = elements_df[['second_name', 'element_type', 'now_cost', 'transfers_in', 'form', 'selected_by_percent', 'total_points', 'value_form', 'value_season', 'clean_sheets' ]]
elements_df.head()
# Out:
#           second_name  element_type  now_cost  transfers_in  form  \
# 315  Borges Fernandes             3       120             0   0.0
# 416              Kane             4       125             0   0.0
# 267             Salah             3       125             0   0.0
# 418               Son             3       100             0   0.0
# 241           Bamford             4        80             0   0.0
#
#      selected_by_percent  total_points  value_form  value_season  clean_sheets
# 315                 48.6           244         0.0          20.3            13
# 416                 21.7           242         0.0          19.4            12
# 267                 50.3           231         0.0          18.5            11
# 418                 21.4           228         0.0          22.8            13
# 241                 20.1           194         0.0          24.2            10

# %%
# convert strings to float
elements_df[['form', 'selected_by_percent', 'value_form', 'value_season']] = elements_df[['form', 'selected_by_percent', 'value_form', 'value_season']].astype(float)

# %%
group_by_e_df = elements_df[elements_df['total_points'] > 0]
group_by_df = group_by_e_df.groupby('element_type').agg({'value_season': np.mean, 'total_points': np.sum})
group_by_df.head()
# Out:
#               value_season  total_points
# element_type
# 1                14.817647          2572
# 2                13.777165          8752
# 3                11.826994         11889
# 4                11.214894          3922

# %%
elements_df.sort_values('value_season', ascending = False, inplace = True)
elements_df.head(11)
# Out:
#              second_name  element_type  now_cost  transfers_in  form  \
# 32              Martínez             1        55             0   0.0
# 240               Dallas             3        55             0   0.0
# 251              Meslier             1        50             0   0.0
# 481            Cresswell             2        55             0   0.0
# 162               Guaita             1        45             0   0.0
# 40               Targett             2        50             0   0.0
# 412               Lloris             1        55             0   0.0
# 252             Harrison             3        60             0   0.0
# 293    Santana de Moraes             1        60             0   0.0
# 478            Fabianski             1        50             0   0.0
# 500  dos Santos Patrício             1        50             0   0.0
#
#      selected_by_percent  total_points  value_form  value_season  clean_sheets
# ...

# %%
elements_df.sort_values('total_points', ascending = False, inplace = True)
elements_df.head(20)
# Out:
#            second_name  element_type  now_cost  transfers_in  form  \
# 315   Borges Fernandes             3       120             0   0.0
# 416               Kane             4       125             0   0.0
# 267              Salah             3       125             0   0.0
# 418                Son             3       100             0   0.0
# 241            Bamford             4        80             0   0.0
# 214              Vardy             4       105             0   0.0
# 32            Martínez             1        55             0   0.0
# 264               Mané             3       120             0   0.0
# 319           Rashford             3        95             0   0.0
# 240             Dallas             3        55             0   0.0
# 41             Watkins             4        75             0   0.0
# 198      Calvert-Lewin             4        80             0   0.0
# 268          Robertson             2        70             0   0.0
# ...

# %%
# filter_elements_df.sort_values('selected_by_percent', ascending = False, inplace = True)
# separate by positions
st_df = elements_df[elements_df['element_type'] == 4]
mid_df = elements_df[elements_df['element_type'] == 3]
def_df = elements_df[elements_df['element_type'] == 2]
gk_df = elements_df[elements_df['element_type'] == 1]

# %%
def_df.sort_values('total_points', ascending = False, inplace = True)
def_df.head(30)
# Out:
# <ipython-input-31-cc0b7d30ab52>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   def_df.sort_values('total_points', ascending = False, inplace = True)
#           second_name  element_type  now_cost  transfers_in  form  \
# 268         Robertson             2        70             0   0.0
# 271  Alexander-Arnold             2        75             0   0.0
# 481         Cresswell             2        55             0   0.0
# 325       Wan-Bissaka             2        55             0   0.0
# 298   Gato Alves Dias             2        60             0   0.0
# 151          Chilwell             2        60             0   0.0
# 40            Targett             2        50             0   0.0
# 292           Cancelo             2        60             0   0.0
# ...

# %%
mid_df.sort_values('total_points', ascending = False, inplace = True)
mid_df.head(50)
# Out:
# <ipython-input-32-56534b2471dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mid_df.sort_values('total_points', ascending = False, inplace = True)
#                    second_name  element_type  now_cost  transfers_in  form  \
# 315           Borges Fernandes             3       120             0   0.0
# 267                      Salah             3       125             0   0.0
# 418                        Son             3       100             0   0.0
# 264                       Mané             3       120             0   0.0
# 319                   Rashford             3        95             0   0.0
# 240                     Dallas             3        55             0   0.0
# 252                   Harrison             3        60             0   0.0
# ...

# %%
st_df.sort_values('total_points', ascending = False, inplace = True)
st_df.head(10)
# Out:
# <ipython-input-33-5203dc45b701>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_df.sort_values('total_points', ascending = False, inplace = True)
#        second_name  element_type  now_cost  transfers_in  form  \
# 416           Kane             4       125             0   0.0
# 241        Bamford             4        80             0   0.0
# 214          Vardy             4       105             0   0.0
# 41         Watkins             4        75             0   0.0
# 198  Calvert-Lewin             4        80             0   0.0
# 262        Firmino             4        90             0   0.0
# 123           Wood             4        70             0   0.0
# 398          Adams             4        70             0   0.0
# 339         Wilson             4        75             0   0.0
# ...

# %%
mid_df.sort_values('total_points', ascending = False, inplace = True)
mid_df.head(40)
# Out:
# <ipython-input-34-5e6fc93c3725>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mid_df.sort_values('total_points', ascending = False, inplace = True)
#           second_name  element_type  now_cost  transfers_in  form  \
# 315  Borges Fernandes             3       120             0   0.0
# 267             Salah             3       125             0   0.0
# 418               Son             3       100             0   0.0
# 264              Mané             3       120             0   0.0
# 319          Rashford             3        95             0   0.0
# 240            Dallas             3        55             0   0.0
# 252          Harrison             3        60             0   0.0
# 286          Gündogan             3        75             0   0.0
# ...

# %%
def_df.sort_values('total_points', ascending = False, inplace = True)
def_df.head(20)
# Out:
# <ipython-input-35-3f8d66ac8402>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   def_df.sort_values('total_points', ascending = False, inplace = True)
#           second_name  element_type  now_cost  transfers_in  form  \
# 268         Robertson             2        70             0   0.0
# 271  Alexander-Arnold             2        75             0   0.0
# 481         Cresswell             2        55             0   0.0
# 325       Wan-Bissaka             2        55             0   0.0
# 298   Gato Alves Dias             2        60             0   0.0
# 151          Chilwell             2        60             0   0.0
# 40            Targett             2        50             0   0.0
# 292           Cancelo             2        60             0   0.0
# ...

# %%
gk_df.sort_values('total_points', ascending = False, inplace = True)
gk_df.head(10)
# Out:
# <ipython-input-36-cdda9e1ac7cd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gk_df.sort_values('total_points', ascending = False, inplace = True)
#              second_name  element_type  now_cost  transfers_in  form  \
# 32              Martínez             1        55             0   0.0
# 293    Santana de Moraes             1        60             0   0.0
# 251              Meslier             1        50             0   0.0
# 412               Lloris             1        55             0   0.0
# 126                 Pope             1        55             0   0.0
# 159                Mendy             1        60             0   0.0
# 265        Ramses Becker             1        60             0   0.0
# 478            Fabianski             1        50             0   0.0
# ...

# %%
def process_total_by_val(points, cost):
    return points/cost

# %%
st_df['total_by_val'] = np.vectorize(process_total_by_val)(st_df['total_points'], st_df['now_cost'])
st_df.sort_values('value_season', ascending = False)
st_df.head(10)
# Out:
# <ipython-input-38-f3e92b19ba5a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_df['total_by_val'] = np.vectorize(process_total_by_val)(st_df['total_points'], st_df['now_cost'])
#        second_name  element_type  now_cost  transfers_in  form  \
# 416           Kane             4       125             0   0.0
# 241        Bamford             4        80             0   0.0
# 214          Vardy             4       105             0   0.0
# 41         Watkins             4        75             0   0.0
# 198  Calvert-Lewin             4        80             0   0.0
# 262        Firmino             4        90             0   0.0
# 123           Wood             4        70             0   0.0
# ...

# %%
st_df.sort_values('total_points', ascending = False, inplace = True)
st_df.head(10)
# Out:
# <ipython-input-39-5203dc45b701>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   st_df.sort_values('total_points', ascending = False, inplace = True)
#        second_name  element_type  now_cost  transfers_in  form  \
# 416           Kane             4       125             0   0.0
# 241        Bamford             4        80             0   0.0
# 214          Vardy             4       105             0   0.0
# 41         Watkins             4        75             0   0.0
# 198  Calvert-Lewin             4        80             0   0.0
# 262        Firmino             4        90             0   0.0
# 123           Wood             4        70             0   0.0
# 398          Adams             4        70             0   0.0
# 339         Wilson             4        75             0   0.0
# ...

# %%
def_df.sort_values('value_season', ascending = False, inplace = True)
def_df.head()
# Out:
# <ipython-input-40-ff98ea94d3ec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   def_df.sort_values('value_season', ascending = False, inplace = True)
#      second_name  element_type  now_cost  transfers_in  form  \
# 481    Cresswell             2        55             0   0.0
# 40       Targett             2        50             0   0.0
# 325  Wan-Bissaka             2        55             0   0.0
# 92          Dunk             2        50             0   0.0
# 39         Mings             2        50             0   0.0
#
#      selected_by_percent  total_points  value_form  value_season  clean_sheets
# 481                 19.4           153         0.0          27.8            11
# 40                   9.9           138         0.0          27.6            16
# ...

# %%
teams_df = pd.DataFrame(json['teams'])

# %%
teams_df.head()
# Out:
#    code  draw  form  id  loss         name  played  points  position  \
# 0     3     0  None   1     0      Arsenal       0       0         0
# 1     7     0  None   2     0  Aston Villa       0       0         0
# 2    94     0  None   3     0    Brentford       0       0         0
# 3    36     0  None   4     0     Brighton       0       0         0
# 4    90     0  None   5     0      Burnley       0       0         0
#
#   short_name  ...  team_division unavailable  win  strength_overall_home  \
# 0        ARS  ...           None       False    0                   1200
# 1        AVL  ...           None       False    0                   1100
# 2        BRE  ...           None       False    0                   1010
# 3        BHA  ...           None       False    0                   1100
# 4        BUR  ...           None       False    0                   1060
#
#    strength_overall_away  strength_attack_home  strength_attack_away  \
# ...

# %%
teams_df.columns
# Out:
# Index(['code', 'draw', 'form', 'id', 'loss', 'name', 'played', 'points',
#        'position', 'short_name', 'strength', 'team_division', 'unavailable',
#        'win', 'strength_overall_home', 'strength_overall_away',
#        'strength_attack_home', 'strength_attack_away', 'strength_defence_home',
#        'strength_defence_away', 'pulse_id'],
#       dtype='object')

# %%
teams_df = teams_df[['short_name', 'form', 'strength_defence_home', 'strength_defence_away', 'strength']]
teams_df.head()
# Out:
#   short_name  form  strength_defence_home  strength_defence_away  strength
# 0        ARS  None                   1220                   1210         4
# 1        AVL  None                   1080                   1100         3
# 2        BRE  None                   1020                   1030         2
# 3        BHA  None                   1100                   1130         3
# 4        BUR  None                   1040                   1080         2

# %%
teams_df.sort_values('strength_defence_home')
# Out:
#    short_name  form  strength_defence_home  strength_defence_away  strength
# 17        WAT  None                   1010                   1040         2
# 6         CRY  None                   1010                   1020         3
# 2         BRE  None                   1020                   1030         2
# 14        NOR  None                   1020                   1030         2
# 13        NEW  None                   1030                   1110         2
# 19        WOL  None                   1040                   1120         3
# 4         BUR  None                   1040                   1080         2
# 1         AVL  None                   1080                   1100         3
# 3         BHA  None                   1100                   1130         3
# 15        SOU  None                   1110                   1160         3
# 8         LEI  None                   1150                   1230         4
# ...

# %%
def avr_defense(home, away):
    return (home + away) / 2

# %%
teams_df['avr_def'] = np.vectorize(avr_defense)(teams_df['strength_defence_home'], teams_df['strength_defence_away'])
teams_df.sort_values('avr_def', ascending = False, inplace = True)
teams_df.head(10)
# Out:
#    short_name  form  strength_defence_home  strength_defence_away  strength  \
# 11        MCI  None                   1340                   1350         5
# 5         CHE  None                   1250                   1310         4
# 18        WHU  None                   1260                   1290         4
# 12        MUN  None                   1240                   1310         4
# 16        TOT  None                   1250                   1290         4
# 10        LIV  None                   1300                   1230         4
# 0         ARS  None                   1220                   1210         4
# 8         LEI  None                   1150                   1230         4
# 9         LEE  None                   1210                   1170         3
# 7         EVE  None                   1200                   1140         3
#
#     avr_def
# 11   1345.0
# 5    1280.0
# 18   1275.0
# 12   1275.0
# 16   1270.0
# 10   1265.0
# 0    1215.0
# 8    1190.0
# ...

# %%
gk_df.sort_values('clean_sheets', ascending = False, inplace = True)
gk_df.head()
# Out:
# <ipython-input-48-0231a52291aa>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gk_df.sort_values('clean_sheets', ascending = False, inplace = True)
#            second_name  element_type  now_cost  transfers_in  form  \
# 293  Santana de Moraes             1        60             0   0.0
# 159              Mendy             1        60             0   0.0
# 32            Martínez             1        55             0   0.0
# 412             Lloris             1        55             0   0.0
# 126               Pope             1        55             0   0.0
#
#      selected_by_percent  total_points  value_form  value_season  clean_sheets
# 293                 10.4           160         0.0          26.7            19
# ...
